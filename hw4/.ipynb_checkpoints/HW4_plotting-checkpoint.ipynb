# %% [markdown]
# # Data-X Spring 2019: Homework 04
#
#
# ## Name: Derek Topper
#
# ## SID: 26861675
#
# In this homework, you will do some exercises with plotting.
#
# REMEMBER TO DISPLAY ALL OUTPUTS. If the question asks you to do something, make sure to print your results.

# %% [markdown]
# ### 1.
# ### Data:
# __Data Source__:
# Data file is uploaded to bCourses and is named: __Energy.csv__
#
# The dataset was created by Angeliki Xifara ( Civil/Structural Engineer) and was processed by Athanasios Tsanas, Oxford Centre for Industrial and Applied Mathematics, University of Oxford, UK).
#
# __Data Description__:
#
# The dataset contains eight attributes of a building (or features, denoted by X1...X8) and response being the heating load on the building, y1.
#
# * X1	Relative Compactness
# * X2	Surface Area
# * X3	Wall Area
# *  X4	Roof Area
# *  X5	Overall Height
# * X6	Orientation
# *  X7	Glazing Area
# *  X8	Glazing Area Distribution
# *  y1	Heating Load

# %% [markdown]
# #### Q1.1
# Read the data file in python. Check if there are any NaN values, and print the results.

# %%
# your code
import pandas as pd
energy = pd.read_csv('Energy.csv')
energy = energy.dropna()
energy.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84

# %% [markdown]
# #### Q 1.2
# Describe (using python function) data features in terms of type, distribution range (max and min), and mean values.

# %%
# your code
print(type(energy["X1"]))
print(energy.describe())
# Out:
# <class 'pandas.core.series.Series'>
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1
# count  768.000000  768.00000  768.000000
# mean     0.234375    2.81250   22.307201
# std      0.133221    1.55096   10.090196
# min      0.000000    0.00000    6.010000
# ...

# %% [markdown]
# #### Q 1.3
# Plot feature distributions for all the attributes in the dataset (Hint - Histograms are one way to plot data distributions). This step should give you clues about data sufficiency.

# %%
# your code

df = energy
import matplotlib.pyplot as plt

f = plt.figure()

ax1 = plt.subplot2grid((3,3), (0,0))
ax2 = plt.subplot2grid((3,3), (0,1)) 
ax3 = plt.subplot2grid((3,3), (0,2))
ax4 = plt.subplot2grid((3,3), (1,0))
ax5 = plt.subplot2grid((3,3), (1,1))
ax6 = plt.subplot2grid((3,3), (1,2))
ax7 = plt.subplot2grid((3,3), (2,0)) 
ax8 = plt.subplot2grid((3,3), (2,1))
ax9 = plt.subplot2grid((3,3), (2,2))

ax1.hist(df["X1"], color="Red")
ax2.hist(df["X2"], color="Orange")
ax3.hist(df["X3"], color="Yellow")
ax4.hist(df["X4"], color="Green")
ax5.hist(df["X5"], color="Blue")
ax6.hist(df["X6"], color="Purple")
ax7.hist(df["X7"], color="Black")
ax8.hist(df["X8"], color="Magenta")
ax9.hist(df["Y1"], color="Cyan")

ax1.set_title('X1')
ax2.set_title('X2')
ax3.set_title('X3')
ax4.set_title('X4')
ax5.set_title('X5')
ax6.set_title('X6')
ax7.set_title('X7')
ax8.set_title('X8')
ax9.set_title('Y1')

ax1.set_xlabel('Range')
ax2.set_xlabel('Range')
ax3.set_xlabel('Range')
ax4.set_xlabel('Range')
ax5.set_xlabel('Range')
ax6.set_xlabel('Range')
ax7.set_xlabel('Range')
ax8.set_xlabel('Range')
ax9.set_xlabel('Range')

ax1.set_ylabel('Frequency')
ax2.set_ylabel('Frequency')
ax3.set_ylabel('Frequency')
ax4.set_ylabel('Frequency')
ax5.set_ylabel('Frequency')
ax6.set_ylabel('Frequency')
ax7.set_ylabel('Frequency')
ax8.set_ylabel('Frequency')
ax9.set_ylabel('Frequency')


f.suptitle('Distribution of Each Attribute',fontsize=15, y=1.05) 

f.tight_layout()
f.show()

# %% [markdown]
# #### Q1.4
# Create a combined line and scatter plot for attributes 'X1' and 'X2' with a marker (*). You can choose either of the attributes as x & y.  Label your axes and give a title to your plot.

# %%
# your code

f = plt.figure()
plt.scatter(df["X1"], df["X2"], marker="*")

a = np.sort(df["X1"])[::-1]
b= np.sort(df["X2"])
plt.plot(a,b)
plt.title("Comparison of X1 and X2 Features")
plt.xlabel("Relative Compactness")
plt.ylabel("Surface Area")
# Out:
# Text(0, 0.5, 'Surface Area')

# %% [markdown]
# #### Q1.5
# Create a scatter plot for how 'Wall Area' changes with 'Relative Compactness'. Give different colors for different 'Overall Height' and different bubble sizes by 'Roof Area'. Label the axes and give a title. Add a legend to your plot.

# %%
# your code

plt.scatter(df["X1"], df["X3"], s=df["X4"], c=df["X5"], marker="o")
plt.title("Comparison of Wall Area, Relative Compactness, Overall Height, and Roof Area Features")
plt.xlabel("Relative Compactness")
plt.ylabel("Wall Area")

import matplotlib.patches as mpatches
blue_patch = mpatches.Patch(color='Purple', label='Height: 3.5, Roof Area Larger')
red_patch = mpatches.Patch(color='Yellow', label='Height: 7, Roof Area Smaller')
plt.legend(handles=[blue_patch, red_patch], loc= 4)

plt.show()

# %%
np.unique(df[df["X5"] == 3.5]["X1"])
# Out:
# array([0.62, 0.64, 0.66, 0.69, 0.71, 0.74])

# %% [markdown]
# ### 2.
# #### Q 2.1a.
# Create a dataframe called `icecream` that has column `Flavor` with entries `Strawberry`, `Vanilla`, and `Chocolate` and another column with `Price` with entries `3.50`, `3.00`, and `4.25`. Print the dataframe.

# %%
# your code
icecream = pd.DataFrame(data={'Flavor': ['Strawberry', 'Vanilla', 'Chocolate'], 
                        'Price': [3.50, 3.00, 4.25]})
icecream
# Out:
#        Flavor  Price
# 0  Strawberry   3.50
# 1     Vanilla   3.00
# 2   Chocolate   4.25

# %% [markdown]
# #### Q 2.1b
# Create a bar chart representing the three flavors and their associated prices. Label the axes and give a title.

# %%
# your code
plt.bar(icecream["Flavor"], icecream["Price"])
plt.ylabel("Price")
plt.xlabel("Flavor")
plt.title("Ice Cream Flavor and Price")
# Out:
# Text(0.5, 1.0, 'Ice Cream Flavor and Price')

# %% [markdown]
# #### Q 2.2
# Create 9 random plots in a figure (Hint: There is a numpy function for generating random data).
#
# The top three should be scatter plots (one with green dots, one with purple crosses, and one with blue triangles. The middle three graphs should be a line graph, a horizontal bar chart, and a histogram. The bottom three graphs should be trignometric functions (one sin, one cosine, one tangent). Keep in mind the range and conditions for the trignometric functions.
#
# ##### All these plots should be on the same figure and not 9 independent figures.

# %%
# your code
import numpy as np
x1 = np.random.rand(50, 1)
x2 = np.random.rand(5, 1) 
x3 = np.array([1,2,3,4,5])
x4 = np.array([1,2.5,2.9,4.2,5])
y1 = np.random.rand(50, 1)
y2 = np.random.rand(50, 1)
y3 = np.random.rand(50, 1)
y4 = np.random.rand(5, 1)
y6 = np.array([1,2,3,4,5])

xSin = np.arange(0,4*np.pi,0.1)   
ySin = np.sin(xSin)

xCos = np.arange(0,4*np.pi,0.1)   
yCos = np.cos(xCos)

xTan = np.arange(0,4*np.pi,0.1)   
yTan = np.tan(xTan)


f2 = plt.figure()

ax1 = plt.subplot2grid((3,3), (0,0))
ax2 = plt.subplot2grid((3,3), (0,1)) 
ax3 = plt.subplot2grid((3,3), (0,2))
ax4 = plt.subplot2grid((3,3), (1,0))
ax5 = plt.subplot2grid((3,3), (1,1))
ax6 = plt.subplot2grid((3,3), (1,2))
ax7 = plt.subplot2grid((3,3), (2,0)) 
ax8 = plt.subplot2grid((3,3), (2,1))
ax9 = plt.subplot2grid((3,3), (2,2))

ax1.scatter(x1, y1, color = "Green")
ax2.scatter(x1, y2, color = "Purple", marker = "+")
ax3.scatter(x1, y3, color = "Blue", marker = "v")
ax4.plot(x4, y6)
ax5.barh(x3, y5)
ax6.hist(x3, y5)
ax7.plot(xSin, ySin)
ax8.plot(xCos, yCos)
ax9.plot(xTan, yTan)

f2.suptitle('Various Randomized Graphs',fontsize=15, y=1.05) 

f2.tight_layout()
f2.show()
# Out:
# C:\Users\Derek\Miniconda3\envs\ds100\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# ### 3.
# #### Q 3.1
#
# Load the 'Iris' dataset using seaborn.
# Create a box plot for the attributes 'sepal_length', sepal_width', 'petal_length' and 'petal_width' in the Iris dataset.

# %%
# your code
import seaborn as sns
iris = sns.load_dataset("iris")

ax = sns.boxplot(data=iris, orient="h")
plt.title("Boxplot of Iris Features")

#ax = sns.boxplot(x="day", y="total_bill", data=iris)
# Out:
# Text(0.5, 1.0, 'Boxplot of Iris Features')

# %% [markdown]
# #### Q 3.2
# In a few sentences explain what can you interpret from the above box plot.

# %% [markdown]
# From the above box plot, I can interpret a few things. Firstly, the petal lengths of the irises in the database have a very high range of values. There are many smaller irises and many bigger ones, with an median petal length of around 4.3.  The first quartile is about 1.7 and the third quartile is about 5.1 and thus 50% of the data of the flower petal lengths fall between these two values. This has the largest range of any of the attributes of the flowers, with flowers ranging in length between 1 and 7. I can also interpret that the widths of the sepals and petals have smaller ranges. The median petal width is about 1.3, the first quartile is about 0.4 and the third quartile is about 1.8.  The range of the petal widths run from about 0.1 to about 2.5.  For the sepal widths,  The median is located at about three, the first quartile is located at about 2.8 and the third quartile is at about 3.3. This is the only attribute with outliers and generally have values between 2.2 and 4.1.  Finally the sepal widths have a median value of  about 5.9, a first quartile value of about 5.1 and a third quartile value of about 6.5.  The range of this attribute runs from 4.3 to 7.9.

# %% [markdown]
# #### Q 4.
# The data files needed:
#
# `google_data.txt, ny_temps.txt & yahoo_data.txt`
#
# Use your knowledge with `Python, NumPy, pandas and matplotlib` to reproduce the plot below:
#
# ![](answer.png?raw=true)

# %%
# your code
google = pd.read_csv('google_data.txt', sep="\t")
nytemps = pd.read_csv('ny_temps.txt', sep="\t")
yahoo = pd.read_csv('yahoo_data.txt', sep="\t")

fig, ax1 = plt.subplots()

ax1.plot(yahoo["Modified Julian Date"], yahoo["Stock Value"], color = "Purple")
ax1.plot(google["Modified Julian Date"], google["Stock Value"], color = "Green")

ax2 = ax1.twinx()

ax2.plot(nytemps["Modified Julian Date"], nytemps["Max Temperature"], 
         linestyle='dashed', color = "blue")

ax2.set_ylim([-100,100])

fig.tight_layout()

fig.set_size_inches(16.5, 9.5)

ax1.set_xlabel("Date (MJD)", fontsize= 20)
ax2.set_ylabel("Temperature (°F)", color = "Blue", fontsize= 20)
ax1.set_ylabel("Value (Dollars)", color = "Purple", fontsize= 20)

ax1.tick_params(axis='y', colors='Green', labelsize = 15)
ax2.tick_params(axis='y', colors='Blue', labelsize = 15)
ax1.tick_params(axis='x',labelsize = 15)

#plt.title("New York Temperature, Google, and Yahoo!",fontsize= 30, fontname="Arial Black",fontweight="bold")

figure_title = "New York Temperature, Google, and Yahoo!"

plt.text(52300, 115, figure_title,
         horizontalalignment='center',
         fontsize= 30, fontname="Arial Black",fontweight="bold")

ax1.legend(loc = 6, frameon=False, fontsize=20)
ax2.legend(loc = 6, bbox_to_anchor = (0, 0.435), frameon=False, fontsize=20)

plt.xticks(np.arange(49000, 56000, step=200))
ax1.set_xticklabels(["49000","","","","","50000","","","","","51000","","","","","52000"
                    ,"","","","","53000","","","","","54000","","","","","55000","","","",""])





plt.yticks(np.arange(-150, 101, step=10))
ax2.set_yticklabels(["-150","","","","","-100","","","","","-50","","","","","0"
                   ,"","","","","50","","","","","100"])

#plt.yticks(np.arange(0, 800, step=20))
#ax1.set_yticklabels(["0","","","","","100","","","","","200","","","","","300",
#                     "","","","","400","","","","","500","","","","","600","","","","","700","","","",""])

plt.show()


#Modified Julian Date	Stock Value
#yahoo
